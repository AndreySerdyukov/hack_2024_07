# %% [markdown]
# # Импрот библиотек

# %%
import pandas as pd
import tqdm
import folium
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# # Загружаем данные с координатами всех билбордов из обучающего датасета

# %%
bills = pd.read_excel('bill_coordinate.xlsx')

# %%
bills
# Out:
#              lat        lon  azimuth
# 0      55.573691  37.631423      273
# 1      55.584765  37.712454      232
# 2      55.808425  37.388808      188
# 3      55.674378  37.422364      333
# 4      55.608396  37.766383       54
# ...          ...        ...      ...
# 11802  55.694607  37.676856       93
# 11803  55.776881  37.524088       40
# 11804  55.623283  37.421858      324
# 11805  55.826256  37.629043      114
# 11806  55.756055  37.615090       47
#
# [11807 rows x 3 columns]

# %% [markdown]
# Для дальнейшей работы необходимо перейти к числам с плавающей точкой

# %%
bills['lat'] = bills['lat'].astype(float)
bills['lon'] = bills['lon'].astype(float)

# %% [markdown]
# Для более качественной разметки нашего датасета было решено разделить билборды по районам. Для этого мы нашли границы для каждого района Москвы и визулизировали все районы на карте

# %%
gdf = gpd.read_file('ao.geojson')

# %%
map_center = [gdf.geometry.centroid.y.mean(), gdf.geometry.centroid.x.mean()]
map = folium.Map(location=map_center, zoom_start=10)
for _, row in gdf.iterrows():
    sim_geo = gpd.GeoSeries(row['geometry']).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_json = folium.GeoJson(data=geo_j,
                              style_function=lambda x: {
                                  'fillColor': 'blue',
                                  'color': 'blue',
                                  'fillOpacity': 0.2
                              })
    geo_json.add_to(map)
map
# Out:
# /var/folders/zl/wtf6lxgn593_7tswz2pzs80m0000gn/T/ipykernel_4905/3251401293.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_center = [gdf.geometry.centroid.y.mean(), gdf.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebba33307a672e7cb88e5bb69e3f1357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebba33307a672e7cb88e5bb69e3f1357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebba33307a672e7cb88e5bb69e3f1357 = L.map(
#                 &quot;map_ebba33307a672e7cb88e5bb69e3f1357&quot;,
#                 {
#                     center: [55.71969496535729, 37.50013808653771],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_004c56370084b02cbcff8658d5db0b0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_004c56370084b02cbcff8658d5db0b0f.addTo(map_ebba33307a672e7cb88e5bb69e3f1357);
#
#
#         function geo_json_9998aadec30d811a1351979127e76b03_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2};
#             }
#         }
#
#         function geo_json_9998aadec30d811a1351979127e76b03_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9998aadec30d811a1351979127e76b03 = L.geoJson(null, {
#                 onEachFeature: geo_json_9998aadec30d811a1351979127e76b03_onEachFeature,
#
#                 style: geo_json_9998aadec30d811a1351979127e76b03_styler,
#         });
#
#         function geo_json_9998aadec30d811a1351979127e76b03_add (data) {
#             geo_json_9998aadec30d811a1351979127e76b03
#                 .addData(data);
#         }
#             geo_json_9998aadec30d811a1351979127e76b03_add({&quot;bbox&quot;: [36.8031, 55.14252, 37.47054, 55.56445], &quot;features&quot;: [{&quot;bbox&quot;: [36.8031, 55.14252, 37.47054, 55.56445], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[36.8031, 55.44083], [36.80451, 55.46551], [36.81521, 55.46597], [36.81605, 55.50836], [36.91947, 55.50584], [36.91975, 55.51545], [36.93599, 55.51499], [36.93967, 55.51348], [36.93602, 55.50902], [36.93779, 55.50946], [36.93797, 55.50701], [36.93523, 55.50523], [36.93807, 55.499], [36.93506, 55.49616], [36.97765, 55.49377], [36.97345, 55.45546], [36.98296, 55.45487], [36.98396, 55.45769], [36.98929, 55.45685], [36.9896, 55.45922], [36.99402, 55.45832], [36.99332, 55.45665], [36.99625, 55.45644], [36.99969, 55.45261], [37.00557, 55.45052], [37.00334, 55.4495], [37.00626, 55.44615], [37.01923, 55.44513], [37.02007, 55.45679], [37.03213, 55.45596], [37.03558, 55.45844], [37.03682, 55.46406], [37.06061, 55.46266], [37.05861, 55.45469], [37.08032, 55.4527], [37.08051, 55.45074], [37.0786, 55.45004], [37.08142, 55.44824], [37.08062, 55.44668], [37.08252, 55.44549], [37.08727, 55.44627], [37.08928, 55.44123], [37.09708, 55.44269], [37.10076, 55.44512], [37.09981, 55.44571], [37.11278, 55.44923], [37.10794, 55.44507], [37.11257, 55.44129], [37.1085, 55.43951], [37.11701, 55.43806], [37.11952, 55.4392], [37.11821, 55.43988], [37.12441, 55.44195], [37.13056, 55.44157], [37.13399, 55.44316], [37.13574, 55.43816], [37.13711, 55.4396], [37.13583, 55.44064], [37.1414, 55.44265], [37.14885, 55.43818], [37.15009, 55.43896], [37.09228, 55.46492], [37.09336, 55.4704], [37.11267, 55.4689], [37.13981, 55.47341], [37.13641, 55.48212], [37.13934, 55.48284], [37.1271, 55.48738], [37.12893, 55.48842], [37.12437, 55.49281], [37.12684, 55.49535], [37.12456, 55.49623], [37.12562, 55.49722], [37.1362, 55.50002], [37.13878, 55.51521], [37.13655, 55.51584], [37.13693, 55.51314], [37.11863, 55.51314], [37.11739, 55.51887], [37.11984, 55.51912], [37.11591, 55.53], [37.11992, 55.53141], [37.12251, 55.53837], [37.11356, 55.53895], [37.11518, 55.54745], [37.17599, 55.56445], [37.1771, 55.56232], [37.17514, 55.55928], [37.17657, 55.55667], [37.17529, 55.55622], [37.17662, 55.55444], [37.18622, 55.55717], [37.19172, 55.55261], [37.19816, 55.55343], [37.20105, 55.5542], [37.19824, 55.55608], [37.20269, 55.55464], [37.20688, 55.55601], [37.20534, 55.55844], [37.21195, 55.55896], [37.21431, 55.55742], [37.21195, 55.55556], [37.20906, 55.54837], [37.2115, 55.54679], [37.22011, 55.54645], [37.22095, 55.54897], [37.22274, 55.54656], [37.22971, 55.5477], [37.23268, 55.54612], [37.23851, 55.54682], [37.23876, 55.55029], [37.24115, 55.55118], [37.24238, 55.54912], [37.24162, 55.54391], [37.24629, 55.54403], [37.24909, 55.54667], [37.24867, 55.55], [37.25585, 55.55052], [37.25825, 55.54969], [37.25453, 55.54677], [37.26921, 55.54623], [37.26807, 55.54378], [37.27188, 55.5416], [37.28041, 55.54341], [37.28242, 55.53865], [37.28955, 55.53996], [37.28637, 55.54353], [37.29675, 55.54439], [37.30451, 55.54245], [37.3113, 55.54373], [37.31366, 55.53912], [37.32756, 55.53849], [37.32874, 55.53991], [37.33607, 55.54064], [37.34356, 55.54704], [37.35181, 55.54738], [37.35286, 55.54622], [37.34832, 55.54318], [

# %% [markdown]
# Теперь каждой паре координат, которая у нас есть, присвоимм округ

# %%
# Пример загрузки данных
gdf_polygons = gpd.read_file('ao.geojson')  # Загрузка полигонов административных округов
df_billboards = pd.read_excel('bill_coordinate.xlsx')  # Загрузка данных билбордов

geometry = [Point(xy) for xy in zip(df_billboards['lon'], df_billboards['lat'])]
gdf_billboards = gpd.GeoDataFrame(df_billboards, geometry=geometry)

# Присвоение административного округа каждому билборду
def get_administrative_area(point, gdf_polygons):
    for idx, row in gdf_polygons.iterrows():
        if row['geometry'].contains(point):
            return row['NAME']
    return None

gdf_billboards['Административный округ'] = gdf_billboards['geometry'].apply(lambda x: get_administrative_area(x, gdf_polygons))

# Сохранение результата
gdf_billboards.to_csv('billboards_with_areas.csv', index=False)

# Отображение результата
print(gdf_billboards.head())
# Out:
#          lat        lon  azimuth                   geometry  \
# 0  55.573691  37.631423      273  POINT (37.63142 55.57369)
# 1  55.584765  37.712454      232  POINT (37.71245 55.58476)
# 2  55.808425  37.388808      188  POINT (37.38881 55.80843)
# 3  55.674378  37.422364      333  POINT (37.42236 55.67438)
# 4  55.608396  37.766383       54   POINT (37.76638 55.6084)
#
#   Административный округ
# 0                  Южный
# 1                  Южный
# 2        Северо-Западный
# 3               Западный
# 4                   None

# %%
gdf_billboards
# Out:
#              lat        lon  azimuth                   geometry  \
# 0      55.573691  37.631423      273  POINT (37.63142 55.57369)
# 1      55.584765  37.712454      232  POINT (37.71245 55.58476)
# 2      55.808425  37.388808      188  POINT (37.38881 55.80843)
# 3      55.674378  37.422364      333  POINT (37.42236 55.67438)
# 4      55.608396  37.766383       54   POINT (37.76638 55.6084)
# ...          ...        ...      ...                        ...
# 11802  55.694607  37.676856       93  POINT (37.67686 55.69461)
# 11803  55.776881  37.524088       40  POINT (37.52409 55.77688)
# 11804  55.623283  37.421858      324  POINT (37.42186 55.62328)
# 11805  55.826256  37.629043      114  POINT (37.62904 55.82626)
# 11806  55.756055  37.615090       47  POINT (37.61509 55.75605)
#
#       Административный округ
# 0                      Южный
# 1                      Южный
# 2            Северо-Западный
# 3                   Западный
# 4                       None
# ...                      ...
# 11802                  Южный
# 11803               Северный
# 11804         Новомосковский
# 11805       Северо-Восточный
# 11806            Центральный
#
# [11807 rows x 5 columns]

# %%
gdf_billboards
# Out:
#              lat        lon  azimuth                   geometry  \
# 0      55.573691  37.631423      273  POINT (37.63142 55.57369)
# 1      55.584765  37.712454      232  POINT (37.71245 55.58476)
# 2      55.808425  37.388808      188  POINT (37.38881 55.80843)
# 3      55.674378  37.422364      333  POINT (37.42236 55.67438)
# 4      55.608396  37.766383       54   POINT (37.76638 55.6084)
# ...          ...        ...      ...                        ...
# 11802  55.694607  37.676856       93  POINT (37.67686 55.69461)
# 11803  55.776881  37.524088       40  POINT (37.52409 55.77688)
# 11804  55.623283  37.421858      324  POINT (37.42186 55.62328)
# 11805  55.826256  37.629043      114  POINT (37.62904 55.82626)
# 11806  55.756055  37.615090       47  POINT (37.61509 55.75605)
#
#       Административный округ
# 0                      Южный
# 1                      Южный
# 2            Северо-Западный
# 3                   Западный
# 4                       None
# ...                      ...
# 11802                  Южный
# 11803               Северный
# 11804         Новомосковский
# 11805       Северо-Восточный
# 11806            Центральный
#
# [11807 rows x 5 columns]

# %% [markdown]
# Проверка на уникальные административные районы Москвы (чтобы не попало ничего лишнего и ничего не потерялось)

# %%
gdf_billboards['Административный округ'].unique()
# Out:
# array(['Южный', 'Северо-Западный', 'Западный', None, 'Северо-Восточный',
#        'Юго-Западный', 'Восточный', 'Северный', 'Юго-Восточный',
#        'Центральный', 'Новомосковский', 'Троицкий', 'Зеленоградский'],
#       dtype=object)

# %% [markdown]
# В ходе работы с данными мы обратили внимание на то, что у части точек остался непрсовенный округ. После анализа местоположения билбордов, мы заметили, что все неклассифицированные билборды находятся в Подмосковье. Поэтому мы решили заполнить все пропуски, поставив Подмосковье

# %%
gdf_billboards['Административный округ'].fillna("Подмосковье", inplace=True)
# Out:
# /var/folders/zl/wtf6lxgn593_7tswz2pzs80m0000gn/T/ipykernel_4905/3648792507.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gdf_billboards['Административный округ'].fillna("Подмосковье", inplace=True)

# %%
df = pd.DataFrame(gdf_billboards)
df
# Out:
#              lat        lon  azimuth                   geometry  \
# 0      55.573691  37.631423      273  POINT (37.63142 55.57369)
# 1      55.584765  37.712454      232  POINT (37.71245 55.58476)
# 2      55.808425  37.388808      188  POINT (37.38881 55.80843)
# 3      55.674378  37.422364      333  POINT (37.42236 55.67438)
# 4      55.608396  37.766383       54   POINT (37.76638 55.6084)
# ...          ...        ...      ...                        ...
# 11802  55.694607  37.676856       93  POINT (37.67686 55.69461)
# 11803  55.776881  37.524088       40  POINT (37.52409 55.77688)
# 11804  55.623283  37.421858      324  POINT (37.42186 55.62328)
# 11805  55.826256  37.629043      114  POINT (37.62904 55.82626)
# 11806  55.756055  37.615090       47  POINT (37.61509 55.75605)
#
#       Административный округ
# 0                      Южный
# 1                      Южный
# 2            Северо-Западный
# 3                   Западный
# 4                Подмосковье
# ...                      ...
# 11802                  Южный
# 11803               Северный
# 11804         Новомосковский
# 11805       Северо-Восточный
# 11806            Центральный
#
# [11807 rows x 5 columns]

# %%
df.drop(columns = 'geometry' , inplace = True)

# %%
df.dtypes
# Out:
# lat                       float64
# lon                       float64
# azimuth                     int64
# Административный округ     object
# dtype: object

# %% [markdown]
# Теперь, для более качественной разметки данных, было принято решение присвоить каждой паре координат не только округ, но и район

# %% [markdown]
# Для этого мы нашли координаты границ каждого района Москвы

# %%
data = pd.read_excel('moscow_admin_division_wth_ao.xlsx')
data
# Out:
#             Субъект  min_longitude  min_latitude  max_longitude  max_latitude
# 0             Арбат      37.572060     55.743712      37.612228     55.758061
# 1         Басманный      37.627940     55.750749      37.713525     55.781956
# 2     Замоскворечье      37.615133     55.720280      37.654211     55.749153
# 3    Красносельский      37.628386     55.759797      37.688804     55.792981
# 4         Мещанский      37.612223     55.759120      37.644896     55.797140
# ..              ...            ...           ...            ...           ...
# 120         Крюково      37.144003     55.947901      37.220825     55.999244
# 121       Матушкино      37.177540     55.986998      37.231254     56.018630
# 122         Савёлки      37.209283     55.966915      37.268406     56.004668
# 123          Силино      37.131448     55.980439      37.205714     56.021208
# 124  Старое Крюково      37.173262     55.969236      37.226587     55.991713
#
# [125 rows x 5 columns]

# %%
data['min_latitude'] = data['min_latitude'].astype(float)
data['max_latitude'] = data['max_latitude'].astype(float)
data['min_longitude'] = data['min_longitude'].astype(float)
data['max_longitude'] = data['max_longitude'].astype(float)

# %% [markdown]
# Теперь для каждой пары наших точек присваиваем район

# %%
def get_district(lat, lon, data):
    for index, row in data.iterrows():
        if row['min_latitude'] <= lat <= row['max_latitude'] and row['min_longitude'] <= lon <= row['max_longitude']:
            return row['Субъект']
    return None

# Apply the function to each row in df with tqdm progress bar
#tqdm.pandas()
df['district'] = df.apply(lambda row: get_district(row['lat'], row['lon'], data), axis=1)

# %%
df
# Out:
#              lat        lon  azimuth Административный округ  \
# 0      55.573691  37.631423      273                  Южный
# 1      55.584765  37.712454      232                  Южный
# 2      55.808425  37.388808      188        Северо-Западный
# 3      55.674378  37.422364      333               Западный
# 4      55.608396  37.766383       54            Подмосковье
# ...          ...        ...      ...                    ...
# 11802  55.694607  37.676856       93                  Южный
# 11803  55.776881  37.524088       40               Северный
# 11804  55.623283  37.421858      324         Новомосковский
# 11805  55.826256  37.629043      114       Северо-Восточный
# 11806  55.756055  37.615090       47            Центральный
#
#                      district
# 0           Бирюлёво Западное
# 1          Бирюлёво Восточное
# 2                     Кунцево
# 3         Очаково-Матвеевское
# 4      Орехово-Борисово Южное
# ...                       ...
# 11802               Печатники
# 11803             Хорошёвский
# 11804                    None
# 11805            Останкинский
# 11806                Тверской
#
# [11807 rows x 5 columns]

# %% [markdown]
# И так же, как в ситуации с округом, заменяем пропуски на Подмосковье (данный вывод мы полностью подтвердили, визуализировав все неклассифицированные точки)

# %%
df['district'].fillna("Подмосковье", inplace=True)
# Out:
# /var/folders/zl/wtf6lxgn593_7tswz2pzs80m0000gn/T/ipykernel_4905/2511637939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['district'].fillna("Подмосковье", inplace=True)

# %% [markdown]
# # Влияние цены недвижимости

# %% [markdown]
# Нами была выдвинута гипотеза о том, что средняя стоимость жилья в том или ином районе оказывает непосредственное влияние на стоимость и количество просмотров. Поэтому мы взяли дынные по средней стоимости жилья для каждого района и применили к нашим данным для улучшения качества модели

# %%
nedv = pd.read_excel('недвижимость.xlsx')

# %%
nedv.rename(columns={'Субъект': 'district'}, inplace=True)

# %%
nedv
# Out:
#            district  Стоимость недвижимости
# 0             Арбат                  507328
# 1         Басманный                  327820
# 2     Замоскворечье                  396450
# 3    Красносельский                  384762
# 4         Мещанский                  396696
# ..              ...                     ...
# 120         Крюково                  204297
# 121       Матушкино                  204297
# 122         Савёлки                  204297
# 123          Силино                  204297
# 124  Старое Крюково                  204297
#
# [125 rows x 2 columns]

# %%
df = pd.merge(df, nedv, on='district', how='left')

# %%
df
# Out:
#              lat        lon  azimuth Административный округ  \
# 0      55.573691  37.631423      273                  Южный
# 1      55.584765  37.712454      232                  Южный
# 2      55.808425  37.388808      188        Северо-Западный
# 3      55.674378  37.422364      333               Западный
# 4      55.608396  37.766383       54            Подмосковье
# ...          ...        ...      ...                    ...
# 11802  55.694607  37.676856       93                  Южный
# 11803  55.776881  37.524088       40               Северный
# 11804  55.623283  37.421858      324         Новомосковский
# 11805  55.826256  37.629043      114       Северо-Восточный
# 11806  55.756055  37.615090       47            Центральный
#
#                      district  Стоимость недвижимости
# 0           Бирюлёво Западное                204613.0
# 1          Бирюлёво Восточное                204613.0
# 2                     Кунцево                289554.0
# 3         Очаково-Матвеевское                288025.0
# 4      Орехово-Борисово Южное                231958.0
# ...                       ...                     ...
# 11802               Печатники                256271.0
# 11803             Хорошёвский                313613.0
# 11804             Подмосковье                     NaN
# 11805            Останкинский                279405.0
# 11806                Тверской                480487.0
#
# [11807 rows x 6 columns]

# %% [markdown]
# Так как в данных пристуствуют пропуски, нами была проделана аналитическая работа по нахождению оптимальной стоимости, которой мы заполним наши nan. Было выбрано число: 200000, поскольку большинство координат без присваивания цены опять были в Подмосковье

# %%
df['Стоимость недвижимости'] = df['Стоимость недвижимости'].fillna(200000)

# %%
df
# Out:
#              lat        lon  azimuth Административный округ  \
# 0      55.573691  37.631423      273                  Южный
# 1      55.584765  37.712454      232                  Южный
# 2      55.808425  37.388808      188        Северо-Западный
# 3      55.674378  37.422364      333               Западный
# 4      55.608396  37.766383       54            Подмосковье
# ...          ...        ...      ...                    ...
# 11802  55.694607  37.676856       93                  Южный
# 11803  55.776881  37.524088       40               Северный
# 11804  55.623283  37.421858      324         Новомосковский
# 11805  55.826256  37.629043      114       Северо-Восточный
# 11806  55.756055  37.615090       47            Центральный
#
#                      district  Стоимость недвижимости
# 0           Бирюлёво Западное                204613.0
# 1          Бирюлёво Восточное                204613.0
# 2                     Кунцево                289554.0
# 3         Очаково-Матвеевское                288025.0
# 4      Орехово-Борисово Южное                231958.0
# ...                       ...                     ...
# 11802               Печатники                256271.0
# 11803             Хорошёвский                313613.0
# 11804             Подмосковье                200000.0
# 11805            Останкинский                279405.0
# 11806                Тверской                480487.0
#
# [11807 rows x 6 columns]

# %%
quantiles = df['Стоимость недвижимости'].quantile([0.2, 0.4, 0.6 , 0.8])
quantiles
# Out:
# 0.2    222055.0
# 0.4    248837.0
# 0.6    283692.0
# 0.8    357036.0
# Name: Стоимость недвижимости, dtype: float64

# %%
bins = [float('-inf'), quantiles[0.2], quantiles[0.4], quantiles[0.6], quantiles[0.8], float('inf')]
labels = ['Дешево', 'Ниже среднего', 'Средне', 'Дорого', 'Очень дорого']
df['Группа стоимости'] = pd.cut(df['Стоимость недвижимости'], bins=bins, labels=labels)

# %%
df.rename(columns = {'district': "Район"} , inplace = True)

# %%
df.drop(columns = 'Стоимость недвижимости', inplace = True)

# %%
df.to_excel('for_back.xlsx' , index = False)

# %%
df.isna().sum()
# Out:
# lat                       0
# lon                       0
# azimuth                   0
# Административный округ    0
# Район                     0
# Группа стоимости          0
# dtype: int64

# %% [markdown]
# # Финальный датасет

# %% [markdown]
# Таким образом, мы получили наш финальный расширенный датасет, на котором можно обучать нашу модель

# %%
df
# Out:
#              lat        lon  azimuth Административный округ  \
# 0      55.573691  37.631423      273                  Южный
# 1      55.584765  37.712454      232                  Южный
# 2      55.808425  37.388808      188        Северо-Западный
# 3      55.674378  37.422364      333               Западный
# 4      55.608396  37.766383       54            Подмосковье
# ...          ...        ...      ...                    ...
# 11802  55.694607  37.676856       93                  Южный
# 11803  55.776881  37.524088       40               Северный
# 11804  55.623283  37.421858      324         Новомосковский
# 11805  55.826256  37.629043      114       Северо-Восточный
# 11806  55.756055  37.615090       47            Центральный
#
#                         Район Группа стоимости
# 0           Бирюлёво Западное           Дешево
# 1          Бирюлёво Восточное           Дешево
# 2                     Кунцево           Дорого
# 3         Очаково-Матвеевское           Дорого
# 4      Орехово-Борисово Южное    Ниже среднего
# ...                       ...              ...
# 11802               Печатники           Средне
# 11803             Хорошёвский           Дорого
# 11804             Подмосковье           Дешево
# 11805            Останкинский           Средне
# 11806                Тверской     Очень дорого
#
# [11807 rows x 6 columns]
